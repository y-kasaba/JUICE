# %% [markdown]
# # JUICE RPWI HF SID4 & 20 (Burst): L1a QL -- 2024/8/25

# %% [markdown]
# # Import lib

# %%
import copy
import datetime
import glob
import math
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import numpy as np
import sys

# %% [markdown]
# # CDF and Directory setting: set by User

# %%
# The latest CDF library https://spdf.gsfc.nasa.gov/pub/software/cdf/dist/latest/
from spacepy import pycdf

import os
os.environ["CDF_LIB"] = "/Applications/cdf/cdf39_1-dist/lib"

# *** Library ***
sys.path.append('./lib/')
import juice_cal_lib   as juice_cal
import juice_cdf_lib   as juice_cdf
import juice_math_lib  as juice_math
import juice_sid20_lib as juice_sid20
import juice_spec_lib  as juice_spec

# %% [markdown]
# # Setting and Read CDF file: set by User

# %%
# *** Plot dump ***
dump_mode = 0                           # 0: no-dump  1:plot dump
# *** CAL ***
unit_mode = 4                           # [Power]     0: raw     1: V＠ADC     2: V@HF    3: V@RWI  4: V/m
band_mode = 1                           # [Power]     0: sum     1: /Hz
cal_mode  = 0                           # [Power]     0: background     1: CAL     2: all
# *** Unit ***
f_mode    = 1                           # [Frequency] 0: linear  1: log
time_mode = 0                           # [Time]      0: Epoch   1: data number
gap_mode  = 1                           # [gap]       0: n/a     1: gap
# *** Frenquency in Linear ***
# f_mode_min = 3000;  f_mode_max = 10000  # 80 - 2068 : SID-4/20
# *** Power range ***
p_raw_max = 8.5                         # background: 7.5   CAL: 10
p_raw_min = 1.0                         # background: 2.5   CAL: 5
# *** Directory set: set by User ***
work_dir = '/Users/user/0-python/JUICE_python/ql/'   # Plot dump folder

# %%
N_ch0     = 4                           # [channel]   2: 2-ch    3: 3-ch                     >3: any
comp_mode = 4                           # [Complex]   0: Poweer  1: Matrix   3: Matrix-2D    >3: any

# %%
E_min = '2024-08-19 21:05:00';  t_min = datetime.datetime.strptime(E_min, "%Y-%m-%d %H:%M:%S")
E_max = '2024-08-19 21:10:00';  t_max = datetime.datetime.strptime(E_max, "%Y-%m-%d %H:%M:%S")
t_min = 0;  t_max = 0

# %%
# *** Flight data: Ver.2 ***
"""
# 20240126
data_dir = '/Users/user/0-python/JUICE_data/Data-CDF/2024/01/26/'
sid = 4;    data_name_list = ['JUICE_L1a_RPWI-HF-SID4_20240126T113727_V01.cdf' ]
sid = 20
data_name_list = ['JUICE_L1a_RPWI-HF-SID20_20240126T113714_V01.cdf',
                  'JUICE_L1a_RPWI-HF-SID20_20240126T114800_V01.cdf',
                 ]
# 202407 -- CO2
data_dir = '/Users/user/Dropbox-Univ/data/data-JUICE/datasets/2024/07/06/'
sid = 4;    data_name_list = ['JUICE_L1a_RPWI-HF-SID4_20240706T121439_V01.cdf']
sid = 20;   data_name_list = ['JUICE_L1a_RPWI-HF-SID20_20240706T121424_V01.cdf']
"""
# 202408 -- CO2
data_dir = '/Users/user/Dropbox-Univ/data/data-JUICE/datasets/2024/08/19/'
sid = 4;    data_name_list = ['JUICE_L1a_RPWI-HF-SID4_20240819T203025_V01.cdf']
sid = 20;   data_name_list = ['JUICE_L1a_RPWI-HF-SID20_20240819T203013_V01.cdf']
"""
"""

# %%
# *** Ground Test - Ver.2 ***
"""
# 202310 -- SAMPLE
data_dir = '/Users/user/0-python/JUICE_data/test-CCSDS/sample/cdf/'
sid = 4
data_name_list = [#'SID04_20231024-0042.cdf',
                  'SID04-comp0-20231117-1529.cdf',          # 10/10/0mV, 0/90/0deg
                  'SID04-comp1-20231117-1532.cdf',          # 10/10/0mV, 0/90/0deg
                  ]
sid = 20;  
data_name_list = [#'SID20_20231024-0042.cdf',
                  'SID20-comp0-20231117-1529.cdf',          # 10/10/0mV, 0/90/0deg
                  'SID20-comp1-20231117-1532.cdf',          # 10/10/0mV, 0/90/0deg
                 ]
# 202310 -- FS
data_dir = '/Users/user/0-python/JUICE_data/test-TMIDX/202311_FS/cdf/'
sid = 4
data_name_list = ['SID04_Seq01.cdf',
                  'SID04_Seq02.cdf',
                  'SID04_Seq16.cdf',
                  'SID04_Seq18.cdf',
                  'SID04_Seq19.cdf',
                  'SID04_Seq20.cdf',
                  ]
sid = 20
data_name_list = ['SID20_Seq01.cdf',
                  'SID20_Seq02.cdf',
                  'SID20_Seq16.cdf',
                  'SID20_Seq18.cdf',
                  'SID20_Seq19.cdf',
                  'SID20_Seq20.cdf',
                  ]
# 202312 -- Checkout
data_dir = '/Users/user/0-python/JUICE_data/test-TMIDX/202312_C/cdf/'
sid = 4;   data_name_list = ['SID4_RPWI_NEWv2_SCI.cdf']
sid = 20;  data_name_list = ['SID20_RPWI_NEWv2_SCI.cdf']
# 202402 -- Ver.3
data_dir = '/Users/user/0-python/JUICE_data/test-CCSDS/IRFU/cdf/'
sid = 20;   data_name_list = ['JUICE_L1a_RPWI-HF-SID20_20240201.cdf']
# 202405 -- dryrun check
data_dir = '/Users/user/0-python/JUICE_data/CCSDS_test_v2/test_TMIDX/2405_dryrun_test/2_LGA-dryrun/'   
sid = 4
data_name_list = ['JUICE_L1a_RPWI-HF-SID4_20000108T053334-20000108T054137_V01___TMIDX_00000.bin.cdf',   # pc2_LGA-dryrun_RPW-SEQ-01a-1_2024_05_15_15_30_16/TM00
                  'JUICE_L1a_RPWI-HF-SID4_20000108T054148-20000108T054316_V01___TMIDX_00001.bin.cdf',   # pc2_LGA-dryrun_RPW-SEQ-01a-1_2024_05_15_15_30_16/TM01
                  'JUICE_L1a_RPWI-HF-SID4_20000108T061111-20000108T061524_V01___TMIDX_00000.bin.cdf',   # pc2_LGA-dryrun_RPW-SEQ-01a-2_2024_05_15_16_07_58
                 ]
sid = 20
data_name_list = ['JUICE_L1a_RPWI-HF-SID20_20000108T053322-20000108T054141_V01___TMIDX_00000.bin.cdf',  # pc2_LGA-dryrun_RPW-SEQ-01a-1_2024_05_15_15_30_16/TM00
                  'JUICE_L1a_RPWI-HF-SID20_20000108T054142-20000108T054318_V01___TMIDX_00001.bin.cdf',  # pc2_LGA-dryrun_RPW-SEQ-01a-1_2024_05_15_15_30_16/TM01
                  'JUICE_L1a_RPWI-HF-SID20_20000108T061058-20000108T061531_V01___TMIDX_00000.bin.cdf',  # pc2_LGA-dryrun_RPW-SEQ-01a-2_2024_05_15_16_07_58
                 ]
"""

# %%
# *** Group read
"""
data_dir = '/Users/user/0-python/JUICE_data/Data-CDF/2023/05/23/'        # CDF data folder
# sid =  4; data_name = '*SID04*.cdf'
sid = 20; data_name = '*SID20*.cdf'
cdf_file = data_dir + data_name
data_name_list = glob.glob(cdf_file)
num_list = len(data_name_list)
data_name_list.sort()
for i in range(num_list):
    data_name_list[i] = os.path.split(data_name_list[i])[1]
"""

# %% [markdown]
# # get CDF data

# %%
class struct:
    pass

data = struct()
num_list = len(data_name_list)
for i in range(num_list):
    data_name = data_name_list[i];  cdf_file = data_dir + data_name;  print(i, cdf_file)
    cdf = pycdf.CDF(cdf_file);      data1 = juice_sid20.hf_sid20_read(cdf, sid)
    if i==0:
        data = data1;                                       print("sid", sid, data.EuEu.shape)
    else:
        data = juice_sid20.hf_sid20_add(data, data1, sid);  print("sid", sid, data.EuEu.shape)
data_name = os.path.split(data_name)[1];                    print("data name:", data_name)

# %%
data = juice_sid20.hf_sid20_shaping(data, sid, cal_mode, N_ch0, comp_mode)

# %%
date1 = data.epoch[0];  date1 = date1.strftime('%Y/%m/%d %R:%S')
date2 = data.epoch[-1]; date2 = date2.strftime('%Y/%m/%d %R:%S')
str_date = date1 + "  -  " + date2

n_time0 = data.EuEu.shape[0];   n_freq0 = data.EuEu.shape[1]
f_min0 = data.frequency[0][0];  f_max0 = (max(np.ravel(data.frequency)))

print("date and time:", str_date)
print("    data size:", data.EuEu.shape, n_time0, n_freq0)
print("    Frequency:", f_min0,  "-", f_max0, "kHz")

# %%
if N_ch0 > 3:
    N_ch0     = data.U_selected[0] + data.V_selected[0] + data.W_selected[0]
if comp_mode > 3:
    comp_mode = data.complex[0]

N_frequency = data.B0_step[0] * data.B0_subdiv[0]
if (comp_mode == 0):
    N_component = 3;   print("  complex:", comp_mode, " (power 3-ch)              <Table 6.3.2>")
elif (comp_mode == 1):
    N_component = 9;   print("  complex:", comp_mode, " (spectral matrix 3-ch)    <Table 6.3.3>")
else:
    N_component = 21;  print("  complex:", comp_mode, " (3D spectral matrix 3-ch) <Table 6.3.4>")

print("       Ch:", N_ch0, " (U:", data.U_selected[0], "  V:", data.V_selected[0], "  W:", data.W_selected[0], ")")
print("       ==> Component", N_component, "   Num-frequency", N_frequency, "  Num-sweep:", n_time0)

# %% [markdown]
# # Spectrum Data

# %%
T_HF  = data.T_HF_FPGA[n_time0//2];  T_RWI = (data.T_RWI_CH1[n_time0//2] + data.T_RWI_CH2[n_time0//2])/2
if T_HF  > 199 or T_HF  < -50:
   T_HF  = 25;  data.T_HF_FPGA[:] = math.nan
if T_RWI > 199 or T_RWI < -200:
   T_RWI = 25;  data.T_RWI_CH1[:] = math.nan;  data.T_RWI_CH2[:] = math.nan

# %%
spec = copy.deepcopy(data)
spec = juice_cal.spec_cal(spec, sid, unit_mode, band_mode, T_HF, T_RWI)  # CAL
spec = juice_spec.hf_getspec_angle (spec)                                # Coherency & ange
spec = juice_spec.hf_getspec_stokes(spec)                                # Stokes and Polarization Parameters 
spec = juice_spec.hf_getspec_stokes_3d(spec)                             # 3D Stokes and Polarization Parameters

# %%
p_max0 = p_raw_max + spec.cf/10;     p_min0 = p_raw_min + spec.cf/10
p_max = np.ceil(np.log10( np.amax( [np.amax(spec.EuEv_re), np.amax(spec.EvEw_re), np.amax(spec.EwEu_re), np.amax(spec.EuEv_im), np.amax(spec.EvEw_im), np.amax(spec.EwEu_im)] ) )*5)/5
p_min = p_min0

print("conversion factor:", '{:.1f}'.format(spec.cf), "    MAX-min:", '{:.1f}'.format(p_max), '({:.1f})'.format(p_max0), '{:.1f}'.format(p_min), '({:.1f})'.format(p_min0), "   str_unit:", spec.str)

# %%
print("N_samp:", data.N_samp[0], "   decimation:", juice_cdf._sample_rate(data.decimation[0])) 
peak_E = np.ravel(spec.EuEu[:][:]); peak_f = np.argmax(peak_E); print("Peak EuEu:", '{:.2e}'.format(peak_E[peak_f]), '{:.2e}'.format(peak_E[peak_f]**.5), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])**.5))
peak_E = np.ravel(spec.EvEv[:][:]); peak_f = np.argmax(peak_E); print("Peak EvEv:", '{:.2e}'.format(peak_E[peak_f]), '{:.2e}'.format(peak_E[peak_f]**.5), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])**.5))
peak_E = np.ravel(spec.EwEw[:][:]); peak_f = np.argmax(peak_E); print("Peak EwEw:", '{:.2e}'.format(peak_E[peak_f]), '{:.2e}'.format(peak_E[peak_f]**.5), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])**.5))
#print("T_HF-FPGA", data.T_HF_FPGA)
#print("T_RWI-CH1", data.T_RWI_CH1)
#print("T_RWI-CH2", data.T_RWI_CH2)

# %%
fig = plt.figure(figsize=(12, 16))
ax1 = fig.add_subplot(9, 1, 1)
ax2 = fig.add_subplot(9, 1, 2)
ax3 = fig.add_subplot(9, 1, 3)
ax4 = fig.add_subplot(9, 1, 4)
ax5 = fig.add_subplot(9, 1, 5)
ax6 = fig.add_subplot(9, 1, 6)
ax7 = fig.add_subplot(9, 1, 7)
ax8 = fig.add_subplot(9, 1, 8)
ax9 = fig.add_subplot(9, 1, 9)

ax1.plot(np.ravel(spec.EuEu), '-r', linewidth=1.2, label='uu')
ax1.plot(np.ravel(spec.EvEv), '-g', linewidth=0.8, label='vv')
ax1.plot(np.ravel(spec.EwEw), '-b', linewidth=0.5, label='ww')
ax1.set_yscale('log')
#
if comp_mode > 0:    # Matrix
    ax2.plot(np.ravel(spec.EuEv_re), '-r', linewidth=1.0, label='uv_re')
    ax2.plot(np.ravel(spec.EvEw_re), '-g', linewidth=0.8, label='vw_re')
    ax2.plot(np.ravel(spec.EwEu_re), '-b', linewidth=0.6, label='wu_re')
    ax2.plot(np.ravel(spec.EuEv_im), ':r', linewidth=1.2,  label='uv_im')
    ax2.plot(np.ravel(spec.EvEw_im), ':g', linewidth=1.0,  label='vw_im')
    ax2.plot(np.ravel(spec.EwEu_im), ':b', linewidth=0.8,  label='wu_im')
    #
    ax3.plot(np.ravel(spec.E_DoPuv), '-r', linewidth=1.0, label='uv')
    ax3.plot(np.ravel(spec.E_DoPvw), '-g', linewidth=0.8, label='vw')
    ax3.plot(np.ravel(spec.E_DoPwu), '-b', linewidth=0.6, label='wu')
    #
    ax4.plot(np.ravel(spec.E_DoLuv), '-r', linewidth=1.0, label='uv')
    ax4.plot(np.ravel(spec.E_DoLvw), '-g', linewidth=0.8, label='vw')
    ax4.plot(np.ravel(spec.E_DoLwu), '-b', linewidth=0.6, label='wu')
    #
    ax5.plot(np.ravel(spec.E_DoCuv), '-r', linewidth=1.0, label='uv')
    ax5.plot(np.ravel(spec.E_DoCvw), '-g', linewidth=0.8, label='vw')
    ax5.plot(np.ravel(spec.E_DoCwu), '-b', linewidth=0.6, label='wu')
    #
    ax6.plot(np.ravel(spec.E_ANGuv), '-r', linewidth=1.0, label='uv')
    ax6.plot(np.ravel(spec.E_ANGvw), '-g', linewidth=0.8, label='vw')
    ax6.plot(np.ravel(spec.E_ANGwu), '-b', linewidth=0.6, label='wu')

ax7.plot(np.ravel(data.frequency),     '-r', linewidth=0.6, label='frequency')
ax7.plot(np.ravel(data.freq_step*10),  '-g', linewidth=0.8, label='step*10')
ax7.plot(np.ravel(data.freq_width*10), ':b', linewidth=1.0, label='width*10')
ax8.plot(np.ravel(data.T_HF_FPGA),  ':r', label='T (HK-FPGA)')
ax8.plot(np.ravel(data.T_RWI_CH1),  ':b', label='T (RWI1)')
ax8.plot(np.ravel(data.T_RWI_CH2),  ':g', label='T (RWI2)')
ax8.plot(np.ravel(data.cal_signal*10), '-k', label='CAL')
ax9.plot(np.ravel(data.epoch), '.')

ax1.set_ylabel(spec.str)
if comp_mode > 0:    # Matrix
    ax2.set_ylabel('Real & Img');          ax3.set_ylabel('Deg. Pol.');    ax4.set_ylabel('Deg. Linear Pol.')
    ax5.set_ylabel('Deg. Circular Pol.');  ax6.set_ylabel('Linear Deg.'); 
ax7.set_ylabel('frequency [kHz]');         ax8.set_ylabel('T [degC]');     ax9.set_ylabel('Date-Time')
ax9.set_xlabel(str_date)
#
title_label = '[JUICE/RPWI HF Burst-Rich (SID-20)]  ' + data_name
ax1.set_title(title_label)
ax1.legend(loc='upper right', fontsize=8); ax7.legend(loc='upper right', fontsize=8);  ax8.legend(loc='upper right', fontsize=8)
if comp_mode > 0:    # Matrix
    ax2.legend(loc='upper right', fontsize=8); ax3.legend(loc='upper right', fontsize=8); 
    ax4.legend(loc='upper right', fontsize=8); ax5.legend(loc='upper right', fontsize=8); ax6.legend(loc='upper right', fontsize=8); 

"""
xlim=[0, N_frequency*1-1]
ax1.set_xlim(xlim); ax2.set_xlim(xlim); ax3.set_xlim(xlim); ax4.set_xlim(xlim); ax5.set_xlim(xlim); ax6.set_xlim(xlim); ax7.set_xlim(xlim)
xlim=[50, 60]; ax8.set_xlim(xlim); ax9.set_xlim(xlim)
ylim=[10**p_raw_min, 10**p_raw_max]
ax1.set_ylim(ylim)
"""
if comp_mode > 0:    # Matrix
    ylim=[-10**p_max, 10**p_max];  ax2.set_ylim(ylim)
    ylim=[-0.05, 1.05]; ax3.set_ylim(ylim); ax4.set_ylim(ylim)
    ylim=[-1.05, 1.05]; ax5.set_ylim(ylim)
    ylim=[-0.05, 185.]; ax6.set_ylim(ylim)
ylim=[f_min0, f_max0]
ax7.set_ylim(ylim)

# Plot
fig.show
if dump_mode == 1:
    png_fname = work_dir+data_name+'_raw.png'
    fig.savefig(png_fname)

# %%
print("Complex:", data.complex)
print("CAL_sig:", data.cal_signal)
print("CAL_onb:", data.onboard_cal)
print("POL_SW :", data.Pol_sep_SW)
print("POL_thr:", data.Pol_sep_thres)

# %%
from datetime import timedelta

# Time resoution: 1/n_block [sec]
Epoch_1d = data.epoch.tolist()
Epoch_2d = []
for i in range(data.N_block[0]):
    Epoch_2d += Epoch_1d
for i in range(n_time0):
    for j in range(data.N_block[0]):
        Epoch_2d[i*data.N_block[0] + j] = Epoch_1d[i] + timedelta(seconds = j/data.N_block[0])

# Frequency
freq_1d       = data.frequency[0].tolist()
freq1         = freq_1d[0:N_frequency]

# %% [markdown]
# ### NaN

# %%
import math
if gap_mode == 1:
    for i in range(n_time0-1):
        if data.scet[i+1]-data.scet[i] > 60:
            print(i, data.epoch[i], i+1, data.epoch[i+1])
            spec.EuEu[i]    = math.nan;  spec.EvEv[i]    = math.nan;  spec.EwEw[i]    = math.nan;  spec.EuEu[i+1]    = math.nan;  spec.EvEv[i+1]    = math.nan;  spec.EwEw[i+1]    = math.nan  
            spec.E_DoLuv[i] = math.nan;  spec.E_DoLvw[i] = math.nan;  spec.E_DoLwu[i] = math.nan;  spec.E_DoLuv[i+1] = math.nan;  spec.E_DoLvw[i+1] = math.nan;  spec.E_DoLwu[i+1] = math.nan
            spec.E_DoCuv[i] = math.nan;  spec.E_DoCvw[i] = math.nan;  spec.E_DoCwu[i] = math.nan;  spec.E_DoCuv[i+1] = math.nan;  spec.E_DoCvw[i+1] = math.nan;  spec.E_DoCwu[i+1] = math.nan        
            spec.E_ANGuv[i] = math.nan;  spec.E_ANGvw[i] = math.nan;  spec.E_ANGwu[i] = math.nan;  spec.E_ANGuv[i+1] = math.nan;  spec.E_ANGvw[i+1] = math.nan;  spec.E_ANGwu[i+1] = math.nan

# %%
# Data for FT plot
spec.EE    = spec.EuEu + spec.EvEv + spec.EwEw
EuEu_2d    = spec.EuEu.reshape   (n_time0 * data.N_block[0], N_frequency);     EuEu_2d =    EuEu_2d.transpose();  EuEu_med    = np.nanmedian(spec.EuEu,    axis=0)
EvEv_2d    = spec.EvEv.reshape   (n_time0 * data.N_block[0], N_frequency);     EvEv_2d =    EvEv_2d.transpose();  EvEv_med    = np.nanmedian(spec.EvEv,    axis=0)
EwEw_2d    = spec.EwEw.reshape   (n_time0 * data.N_block[0], N_frequency);     EwEw_2d =    EwEw_2d.transpose();  EwEw_med    = np.nanmedian(spec.EwEw,    axis=0)
EE_2d      = spec.EE.reshape     (n_time0 * data.N_block[0], N_frequency);     EE_2d   =    EE_2d.transpose();    EE_med      = np.nanmedian(spec.EuEu,    axis=0)
E_DoPuv_2d = spec.E_DoLuv.reshape(n_time0 * data.N_block[0], N_frequency);  E_DoPuv_2d = E_DoPuv_2d.transpose();  E_DoPuv_med = np.nanmedian(spec.E_DoPuv, axis=0)
E_DoPvw_2d = spec.E_DoLvw.reshape(n_time0 * data.N_block[0], N_frequency);  E_DoPvw_2d = E_DoPvw_2d.transpose();  E_DoPvw_med = np.nanmedian(spec.E_DoPvw, axis=0)
E_DoPwu_2d = spec.E_DoLwu.reshape(n_time0 * data.N_block[0], N_frequency);  E_DoPwu_2d = E_DoPwu_2d.transpose();  E_DoPwu_med = np.nanmedian(spec.E_DoPwu, axis=0)
E_DoLuv_2d = spec.E_DoLuv.reshape(n_time0 * data.N_block[0], N_frequency);  E_DoLuv_2d = E_DoLuv_2d.transpose();  E_DoLuv_med = np.nanmedian(spec.E_DoLuv, axis=0)
E_DoLvw_2d = spec.E_DoLvw.reshape(n_time0 * data.N_block[0], N_frequency);  E_DoLvw_2d = E_DoLvw_2d.transpose();  E_DoLvw_med = np.nanmedian(spec.E_DoLvw, axis=0)
E_DoLwu_2d = spec.E_DoLwu.reshape(n_time0 * data.N_block[0], N_frequency);  E_DoLwu_2d = E_DoLwu_2d.transpose();  E_DoLwu_med = np.nanmedian(spec.E_DoLwu, axis=0)
E_DoCuv_2d = spec.E_DoCuv.reshape(n_time0 * data.N_block[0], N_frequency);  E_DoCuv_2d = E_DoCuv_2d.transpose();  E_DoCuv_med = np.nanmedian(spec.E_DoCuv, axis=0)
E_DoCvw_2d = spec.E_DoCvw.reshape(n_time0 * data.N_block[0], N_frequency);  E_DoCvw_2d = E_DoCvw_2d.transpose();  E_DoCvw_med = np.nanmedian(spec.E_DoCvw, axis=0)
E_DoCwu_2d = spec.E_DoCwu.reshape(n_time0 * data.N_block[0], N_frequency);  E_DoCwu_2d = E_DoCwu_2d.transpose();  E_DoCwu_med = np.nanmedian(spec.E_DoCwu, axis=0)
E_ANGuv_2d = spec.E_ANGuv.reshape(n_time0 * data.N_block[0], N_frequency);  E_ANGuv_2d = E_ANGuv_2d.transpose();  E_ANGuv_med = np.nanmedian(spec.E_ANGuv, axis=0)
E_ANGvw_2d = spec.E_ANGvw.reshape(n_time0 * data.N_block[0], N_frequency);  E_ANGvw_2d = E_ANGvw_2d.transpose();  E_ANGvw_med = np.nanmedian(spec.E_ANGvw, axis=0)
E_ANGwu_2d = spec.E_ANGwu.reshape(n_time0 * data.N_block[0], N_frequency);  E_ANGwu_2d = E_ANGwu_2d.transpose();  E_ANGwu_med = np.nanmedian(spec.E_ANGwu, axis=0)
E_COHuv_2d = spec.E_ANGwu.reshape(n_time0 * data.N_block[0], N_frequency);  E_COHuv_2d = E_COHuv_2d.transpose();  E_COHuv_med = np.nanmedian(spec.E_COHuv, axis=0)
E_COHvw_2d = spec.E_ANGwu.reshape(n_time0 * data.N_block[0], N_frequency);  E_COHvw_2d = E_COHvw_2d.transpose();  E_COHvw_med = np.nanmedian(spec.E_COHvw, axis=0)
E_COHwu_2d = spec.E_ANGwu.reshape(n_time0 * data.N_block[0], N_frequency);  E_COHwu_2d = E_COHwu_2d.transpose();  E_COHwu_med = np.nanmedian(spec.E_COHwu, axis=0)
E_PHAuv_2d = spec.E_ANGwu.reshape(n_time0 * data.N_block[0], N_frequency);  E_PHAuv_2d = E_PHAuv_2d.transpose();  E_PHAuv_med = np.nanmedian(spec.E_PHAuv, axis=0)
E_PHAvw_2d = spec.E_ANGwu.reshape(n_time0 * data.N_block[0], N_frequency);  E_PHAvw_2d = E_PHAvw_2d.transpose();  E_PHAvw_med = np.nanmedian(spec.E_PHAvw, axis=0)
E_PHAwu_2d = spec.E_ANGwu.reshape(n_time0 * data.N_block[0], N_frequency);  E_PHAwu_2d = E_PHAwu_2d.transpose();  E_PHAwu_med = np.nanmedian(spec.E_PHAwu, axis=0)

p_max1 = p_raw_max + spec.cf/10; p_min1 = p_raw_min + spec.cf/10
p_max1 = np.ceil(np.log10(np.amax([np.amax(spec.EuEu), np.amax(spec.EvEv), np.amax(spec.EwEw)]))*5)/5

# freq_width_2d = data.freq_width.reshape(n_time0 * data.N_block[0], N_frequency); freq_width_2d = freq_width_2d.transpose()
f_min0 = freq_1d[0];  f_max0 = freq_1d[N_frequency-1]
print(spec.str, "   f_MAX/min:", f_max0, f_min0, "   num of f, step, window:", N_frequency, data.freq_step[0][0], data.freq_width[0][0])
print("Epoch:", data.epoch.shape, "->", len(Epoch_2d))
print(" EuEu:", spec.EuEu.shape, "->", EuEu_2d.shape)

# %% [markdown]
# ## Spec

# %%
# Sweep_num
n0 = 0
n1 = np.int16(n_time0/2)
n2 = n_time0-1  # *5//7
# X-range
f_min = f_min0;  f_max = f_max0
# Y-range
p_min = p_min0;  p_max = p_max0

fig = plt.figure(figsize=(14, 11))
ax1 = fig.add_subplot(4, 1, 1);   ax5 = fig.add_subplot(4, 1, 2);  ax6 = fig.add_subplot(4, 1, 3);  ax7 = fig.add_subplot(4, 1, 4)
# ax4 = fig.add_subplot(6, 1, 5); ax3 = fig.add_subplot(6, 1, 6)

ax1.plot(freq1, spec.EuEu[n0][0:N_frequency], ':r', linewidth=1.0, label='uu init')
ax1.plot(freq1, spec.EvEv[n0][0:N_frequency], ':g', linewidth=0.8, label='vv init')
ax1.plot(freq1, spec.EwEw[n0][0:N_frequency], ':b', linewidth=0.6, label='ww init')
ax1.plot(freq1, spec.EuEu[n1][0:N_frequency], '-.r', linewidth=1.0, label='uu half')
ax1.plot(freq1, spec.EvEv[n1][0:N_frequency], '-.g', linewidth=0.8, label='vv half')
ax1.plot(freq1, spec.EwEw[n1][0:N_frequency], '-.b', linewidth=0.6, label='ww half')
ax1.plot(freq1, spec.EuEu[n2][0:N_frequency], '-r', linewidth=1.0, label='uu end')
ax1.plot(freq1, spec.EvEv[n2][0:N_frequency], '-g', linewidth=0.8, label='vv end')
ax1.plot(freq1, spec.EwEw[n2][0:N_frequency], '-b', linewidth=0.6, label='ww end')
ax1.set_yscale('log')
if f_mode == 1:
    ax1.set_xscale('log')
#
if comp_mode > 0:    # Matrix
    """
    ax3.plot(freq1, spec.EuEv_re[n1][0:N_frequency], '-r', linewidth=1.0, label='uv_re half')
    ax3.plot(freq1, spec.EvEw_re[n1][0:N_frequency], '-g', linewidth=0.8, label='vw_re half')
    ax3.plot(freq1, spec.EwEu_re[n1][0:N_frequency], '-b', linewidth=0.6, label='wu_re half')
    ax3.plot(freq1, spec.EuEv_im[n1][0:N_frequency], ':r', linewidth=1.2,  label='uv_im half')
    ax3.plot(freq1, spec.EvEw_im[n1][0:N_frequency], ':g', linewidth=1.0,  label='vw_im half')
    ax3.plot(freq1, spec.EwEu_im[n1][0:N_frequency], ':b', linewidth=0.8,  label='wu_im half')
    #
    ax4.plot(freq1, spec.E_DoPuv[n0][0:N_frequency], ':r', linewidth=1.0, label='uv init')
    ax4.plot(freq1, spec.E_DoPvw[n0][0:N_frequency], ':g', linewidth=0.8, label='vw init')
    ax4.plot(freq1, spec.E_DoPwu[n0][0:N_frequency], ':b', linewidth=0.6, label='wu init')
    ax4.plot(freq1, spec.E_DoPuv[n1][0:N_frequency], '-.r', linewidth=1.2,  label='uv half')
    ax4.plot(freq1, spec.E_DoPvw[n1][0:N_frequency], '-.g', linewidth=1.0,  label='vw half')
    ax4.plot(freq1, spec.E_DoPwu[n1][0:N_frequency], '-.b', linewidth=0.8,  label='wu half')
    ax4.plot(freq1, spec.E_DoPuv[n2][0:N_frequency], '-r', linewidth=1.2,  label='uv end')
    ax4.plot(freq1, spec.E_DoPvw[n2][0:N_frequency], '-g', linewidth=1.0,  label='vw end')
    ax4.plot(freq1, spec.E_DoPwu[n2][0:N_frequency], '-b', linewidth=0.8,  label='wu end')
    #
    """
    ax5.plot(freq1, spec.E_DoLuv[n0][0:N_frequency], ':r', linewidth=1.0, label='uv init')
    ax5.plot(freq1, spec.E_DoLvw[n0][0:N_frequency], ':g', linewidth=0.8, label='vw init')
    ax5.plot(freq1, spec.E_DoLwu[n0][0:N_frequency], ':b', linewidth=0.6, label='wu init')
    ax5.plot(freq1, spec.E_DoLuv[n1][0:N_frequency], '-.r', linewidth=1.2,  label='uv half')
    ax5.plot(freq1, spec.E_DoLvw[n1][0:N_frequency], '-.g', linewidth=1.0,  label='vw half')
    ax5.plot(freq1, spec.E_DoLwu[n1][0:N_frequency], '-.b', linewidth=0.8,  label='wu half')
    ax5.plot(freq1, spec.E_DoLuv[n2][0:N_frequency], '-r', linewidth=1.2,  label='uv end')
    ax5.plot(freq1, spec.E_DoLvw[n2][0:N_frequency], '-g', linewidth=1.0,  label='vw end')
    ax5.plot(freq1, spec.E_DoLwu[n2][0:N_frequency], '-b', linewidth=0.8,  label='wu end')
    #
    ax6.plot(freq1, spec.E_DoCuv[n0][0:N_frequency], ':r', linewidth=1.0, label='uv init')
    ax6.plot(freq1, spec.E_DoCvw[n0][0:N_frequency], ':g', linewidth=0.8, label='vw init')
    ax6.plot(freq1, spec.E_DoCwu[n0][0:N_frequency], ':b', linewidth=0.6, label='wu init')
    ax6.plot(freq1, spec.E_DoCuv[n1][0:N_frequency], '-.r', linewidth=1.2,  label='uv half')
    ax6.plot(freq1, spec.E_DoCvw[n1][0:N_frequency], '-.g', linewidth=1.0,  label='vw half')
    ax6.plot(freq1, spec.E_DoCwu[n1][0:N_frequency], '-.b', linewidth=0.8,  label='wu half')
    ax6.plot(freq1, spec.E_DoCuv[n2][0:N_frequency], '-r', linewidth=1.2,  label='uv end')
    ax6.plot(freq1, spec.E_DoCvw[n2][0:N_frequency], '-g', linewidth=1.0,  label='vw end')
    ax6.plot(freq1, spec.E_DoCwu[n2][0:N_frequency], '-b', linewidth=0.8,  label='wu end')
    #
    ax7.plot(freq1, spec.E_ANGuv[n0][0:N_frequency], ':r', linewidth=1.0, label='uv init')
    ax7.plot(freq1, spec.E_ANGvw[n0][0:N_frequency], ':g', linewidth=0.8, label='vw init')
    ax7.plot(freq1, spec.E_ANGwu[n0][0:N_frequency], ':b', linewidth=0.6, label='wu init')
    ax7.plot(freq1, spec.E_ANGuv[n1][0:N_frequency], '-.r', linewidth=1.2,  label='uv half')
    ax7.plot(freq1, spec.E_ANGvw[n1][0:N_frequency], '-.g', linewidth=1.0,  label='vw half')
    ax7.plot(freq1, spec.E_ANGwu[n1][0:N_frequency], '-.b', linewidth=0.8,  label='wu half')
    ax7.plot(freq1, spec.E_ANGuv[n2][0:N_frequency], '-r', linewidth=1.2,  label='uv end')
    ax7.plot(freq1, spec.E_ANGvw[n2][0:N_frequency], '-g', linewidth=1.0,  label='vw end')
    ax7.plot(freq1, spec.E_ANGwu[n2][0:N_frequency], '-b', linewidth=0.8,  label='wu end')
    #
    if f_mode == 1:
        ax5.set_xscale('log');  ax6.set_xscale('log');  ax7.set_xscale('log')   # ax3.set_xscale('log');  ax4.set_xscale('log')

# Label
ax1.set_ylabel(spec.str)
if comp_mode > 0:    # Matrix
    ax5.set_ylabel('Deg. Linear Pol.')
    ax6.set_ylabel('Deg. Circular Pol.')
    ax7.set_ylabel('Linear Deg.')
    # ax4.set_ylabel('Deg. Pol.')
    # ax3.set_ylabel('Real & Img')
ax7.set_xlabel('frequency [Hz]')
#
date1 = data.epoch[n0];  date1 = date1.strftime('%Y/%m/%d %R:%S')
date2 = data.epoch[n1];  date2 = date2.strftime('%Y/%m/%d %R:%S')
date3 = data.epoch[n2];  date3 = date3.strftime('%Y/%m/%d %R:%S')
title_date = "[" + data_name + "]  " + date1 + "  -  " + date2 + "  -  " + date3 
ax1.set_title(title_date)
ax1.legend(loc='upper right', fontsize=8)
ax5.legend(loc='upper right', fontsize=8); ax6.legend(loc='upper right', fontsize=8);  ax7.legend(loc='upper right', fontsize=8)
# ax3.legend(loc='upper right', fontsize=8); ax4.legend(loc='upper right', fontsize=8); 

# range: X-axis
xlim=[f_min, f_max]
ax1.set_xlim(xlim); ax5.set_xlim(xlim); ax6.set_xlim(xlim); ax7.set_xlim(xlim); # ax3.set_xlim(xlim); ax4.set_xlim(xlim); 
# range: Y-axis
ylim=[10**p_min, 10**p_max]; ax1.set_ylim(ylim)
if comp_mode > 0:    # Matrix
    ylim=[-0.05, 1.05]; ax5.set_ylim(ylim);  # ax4.set_ylim(ylim); 
    ylim=[-1.05, 1.05]; ax6.set_ylim(ylim)
    ylim=[-0.05, 185.]; ax7.set_ylim(ylim)
    # ylim=[-10**p_raw_max, 10**p_raw_max]; ax3.set_ylim(ylim)

fig.subplots_adjust(hspace=0)
fig.show
if dump_mode == 1:
    png_fname = work_dir+data_name+'_spec.png'
    if f_mode == 1:
        png_fname = work_dir+data_name+'_spec-log.png'
    fig.savefig(png_fname)

# %%
# Peak
print("[First]")
peak_E = spec.EuEu[n0][0:N_frequency]; peak_f = np.argmax(peak_E); print("Peak EuEu:", '{:.2e}'.format(peak_E[peak_f]), "at", '{:.1f}'.format(freq1[peak_f]), "kHz")
peak_E = spec.EvEv[n0][0:N_frequency]; peak_f = np.argmax(peak_E); print("Peak EvEv:", '{:.2e}'.format(peak_E[peak_f]), "at", '{:.1f}'.format(freq1[peak_f]), "kHz")
peak_E = spec.EwEw[n0][0:N_frequency]; peak_f = np.argmax(peak_E); print("Peak EwEw:", '{:.2e}'.format(peak_E[peak_f]), "at", '{:.1f}'.format(freq1[peak_f]), "kHz")
print("[Mid]")
peak_E = spec.EuEu[n1][0:N_frequency]; peak_f = np.argmax(peak_E); print("Peak EuEu:", '{:.2e}'.format(peak_E[peak_f]), "at", '{:.1f}'.format(freq1[peak_f]), "kHz")
peak_E = spec.EvEv[n1][0:N_frequency]; peak_f = np.argmax(peak_E); print("Peak EvEv:", '{:.2e}'.format(peak_E[peak_f]), "at", '{:.1f}'.format(freq1[peak_f]), "kHz")
peak_E = spec.EwEw[n1][0:N_frequency]; peak_f = np.argmax(peak_E); print("Peak EwEw:", '{:.2e}'.format(peak_E[peak_f]), "at", '{:.1f}'.format(freq1[peak_f]), "kHz")
print("[Last]")
peak_E = spec.EuEu[n2][0:N_frequency]; peak_f = np.argmax(peak_E); print("Peak EuEu:", '{:.2e}'.format(peak_E[peak_f]), "at", '{:.1f}'.format(freq1[peak_f]), "kHz")
peak_E = spec.EvEv[n2][0:N_frequency]; peak_f = np.argmax(peak_E); print("Peak EvEv:", '{:.2e}'.format(peak_E[peak_f]), "at", '{:.1f}'.format(freq1[peak_f]), "kHz")
peak_E = spec.EwEw[n2][0:N_frequency]; peak_f = np.argmax(peak_E); print("Peak EwEw:", '{:.2e}'.format(peak_E[peak_f]), "at", '{:.1f}'.format(freq1[peak_f]), "kHz")

# %%
n1 = np.int16(n_time0*3/5)
f_min = f_min0;  f_max = f_max0
p_min = p_min0;  p_max = p_max0

fig = plt.figure(figsize=(14, 11))
ax1 = fig.add_subplot(1, 1, 1)

ax1.plot(freq1, spec.EuEu[n1][0:N_frequency], '-.r', linewidth=1.0, label='uu half')
ax1.plot(freq1, spec.EvEv[n1][0:N_frequency], '-.g', linewidth=0.8, label='vv half')
ax1.plot(freq1, spec.EwEw[n1][0:N_frequency], '-.b', linewidth=0.6, label='ww half')
ax1.plot(freq1, EE_med  [0:N_frequency], '-y', linewidth=2.0, label='EE_med')
ax1.plot(freq1, EuEu_med[0:N_frequency], '-r', linewidth=1.0, label='EuEu_med')
ax1.plot(freq1, EvEv_med[0:N_frequency], '-g', linewidth=1.0, label='EvEv_med')
ax1.plot(freq1, EwEw_med[0:N_frequency], '-b', linewidth=1.0, label='EwEw_med')
ax1.set_yscale('log')
if f_mode == 1:
    ax1.set_xscale('log')

ax1.set_ylabel(spec.str); ax1.set_xlabel('frequency [Hz]')
date2 = data.epoch[n1];  date2 = date2.strftime('%Y/%m/%d %R:%S');  title_date = "[" + data_name + "]  " + date2;  ax1.set_title(title_date)
ax1.legend(loc='upper right', fontsize=8)

xlim=[f_min, f_max]
ax1.set_xlim(xlim); ax5.set_xlim(xlim); ax6.set_xlim(xlim); ax7.set_xlim(xlim); # ax3.set_xlim(xlim); ax4.set_xlim(xlim); 
ylim=[10**p_min, 10**p_max]; 
ax1.set_ylim(ylim)

fig.subplots_adjust(hspace=0);  fig.show
if dump_mode == 1:
    png_fname = work_dir+data_name+'_spec.png'
    if f_mode == 1:
        png_fname = work_dir+data_name+'_spec-log.png'
    fig.savefig(png_fname)

# %%
peak_E = np.ravel(EuEu_med[0:20]); peak_f = np.argmax(peak_E); print("Peak EuEu:", freq_1d[peak_f], '{:.2e}'.format(peak_E[peak_f]), '{:.2e}'.format(peak_E[peak_f]**.5), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])**.5))
peak_E = np.ravel(EvEv_med[0:20]); peak_f = np.argmax(peak_E); print("Peak EvEv:", freq_1d[peak_f], '{:.2e}'.format(peak_E[peak_f]), '{:.2e}'.format(peak_E[peak_f]**.5), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])**.5))
peak_E = np.ravel(EwEw_med[0:20]); peak_f = np.argmax(peak_E); print("Peak EwEw:", freq_1d[peak_f], '{:.2e}'.format(peak_E[peak_f]), '{:.2e}'.format(peak_E[peak_f]**.5), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])), '{:.2e}'.format( (peak_E[peak_f-2]+peak_E[peak_f-1]+peak_E[peak_f]+peak_E[peak_f+1]+peak_E[peak_f+2])**.5))

# %% [markdown]
# ## FT

# %%
f_min = f_min0;      f_max = f_max0
p_min = p_min0+1;    p_max = p_max0-4
num_1d = np.arange(EuEu_2d.shape[1])

fig2d = plt.figure(figsize=[16,11])
if time_mode == 1:
    ax1 = fig2d.add_subplot(4, 1, 1);  ax2 = fig2d.add_subplot(4, 1, 2);  ax3 = fig2d.add_subplot(4, 1, 3);  ax4 = fig2d.add_subplot(4, 1, 4)
    ax4.set_xlabel(str_date)
else:
    ax1 = fig2d.add_subplot(3, 1, 1);  ax2 = fig2d.add_subplot(3, 1, 2);  ax3 = fig2d.add_subplot(3, 1, 3)
    ax3.set_xlabel(str_date)
ax1.set_ylim(f_min, f_max);    ax2.set_ylim(f_min, f_max);    ax3.set_ylim(f_min, f_max)
if f_mode == 1:
    ax1.set_yscale('log');     ax2.set_yscale('log');         ax3.set_yscale('log')
ax1.set_ylabel('EuEu [kHz]');  ax2.set_ylabel('EvEv [kHz]');  ax3.set_ylabel('EwEw [kHz]')
ax1.set_title("[" + data_name + "]")

if time_mode == 1:
    p1 = ax1.pcolormesh(num_1d, freq1, EuEu_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p2 = ax2.pcolormesh(num_1d, freq1, EvEv_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p3 = ax3.pcolormesh(num_1d, freq1, EwEw_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p4 = ax4.plot(np.ravel(Epoch_2d[:]), '.')
    pp3 = fig2d.colorbar(p3, ax=ax4, orientation="vertical"); pp3.set_label(spec.str)
else:
    p1 = ax1.pcolormesh(Epoch_2d, freq1, EuEu_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p2 = ax2.pcolormesh(Epoch_2d, freq1, EvEv_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p3 = ax3.pcolormesh(Epoch_2d, freq1, EwEw_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
pp1 = fig2d.colorbar(p1, ax=ax1, orientation="vertical");  pp1.set_label(spec.str)
pp2 = fig2d.colorbar(p2, ax=ax2, orientation="vertical");  pp2.set_label(spec.str)
pp3 = fig2d.colorbar(p3, ax=ax3, orientation="vertical");  pp3.set_label(spec.str)

print( "(", num_1d[0],")", Epoch_2d[0], "-", "(", num_1d[-1],")", Epoch_2d[-1] )
if time_mode == 1:
    xlim=[num_1d[0], num_1d[-1]]
    # xlim=[num_1d[0], 100]
    ax4.set_xlim(xlim)
else:
    if t_min==0:
        xlim=[Epoch_2d[0], Epoch_2d[-1]]
    else:
        xlim=[t_min, t_max]
    print("==>", xlim)
ax1.set_xlim(xlim); ax2.set_xlim(xlim); ax3.set_xlim(xlim)

plt.subplots_adjust(hspace=.03)
plt.show()
if dump_mode == 1:
    png_fname = work_dir+data_name+'_FT.png'
    if f_mode == 1:
        png_fname = work_dir+data_name+'_FT-log.png'
    fig2d.savefig(png_fname)

# %%
p_min = p_min0+1.2;  p_max = p_max0-2.5
f_min = f_min0;      f_max = f_max0

fig2d = plt.figure(figsize=[16,11])
if time_mode == 1:
    ax1 = fig2d.add_subplot(2, 1, 1);  ax2 = fig2d.add_subplot(2, 1, 2)
else:
    ax1 = fig2d.add_subplot(1, 1, 1)
ax1.set_ylim(f_min, f_max)
if f_mode == 1:
    ax1.set_yscale('log')
ax1.set_ylabel('EE [kHz]')
ax1.set_title("[" + data_name + "]");  ax3.set_xlabel(str_date)

if time_mode == 1:
    p1 = ax1.pcolormesh(num_1d,   freq1, EE_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p2 = ax4.plot(np.ravel(Epoch_2d[:]), '.')
    pp1 = fig2d.colorbar(p1, ax=ax2, orientation="vertical"); pp1.set_label(spec.str)
else:
    p1 = ax1.pcolormesh(Epoch_2d, freq1, EE_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
pp1 = fig2d.colorbar(p1, ax=ax1, orientation="vertical");  pp1.set_label(spec.str)

print( "(", num_1d[0],")", Epoch_2d[0], "-", "(", num_1d[-1],")", Epoch_2d[-1] )
if time_mode == 1:
    xlim=[num_1d[0], num_1d[-1]]
    # xlim=[num_1d[0], 100]
    ax4.set_xlim(xlim)
else:
    if t_min==0:
        xlim=[Epoch_2d[0], Epoch_2d[-1]]
    else:
        xlim=[t_min, t_max]
    print("==>", xlim)
E_min1 = '2024-08-19 21:07:00';  t_min1 = datetime.datetime.strptime(E_min1, "%Y-%m-%d %H:%M:%S")
E_max1 = '2024-08-19 21:08:30';  t_max1 = datetime.datetime.strptime(E_max1, "%Y-%m-%d %H:%M:%S"); xlim=[t_min1, t_max1]
ax1.set_xlim(xlim)

plt.subplots_adjust(hspace=.03);  plt.show()
if dump_mode == 1:
    png_fname = work_dir+data_name+'_FT2.png'
    if f_mode == 1:
        png_fname = work_dir+data_name+'_FT2-log.png'
    fig2d.savefig(png_fname)

# %% [markdown]
# ## Ang-T

# %%
# Y-range
f_min = f_min0;      f_max = f_max0
# f_min = 100;         f_max = 1000
# Z-range
p_min = p_min0;      p_max = p_max0
p_min = p_min0+1;    p_max = p_max0-2

fig2d = plt.figure(figsize=[16,11])
ax1 = fig2d.add_subplot(10, 1, 1);  ax2 = fig2d.add_subplot(10, 1, 2);  ax3 = fig2d.add_subplot(10, 1, 3)
ax4 = fig2d.add_subplot(10, 1, 4);  ax5 = fig2d.add_subplot(10, 1, 5);  ax6 = fig2d.add_subplot(10, 1, 6)
ax7 = fig2d.add_subplot(10, 1, 7);  ax8 = fig2d.add_subplot(10, 1, 8);  ax9 = fig2d.add_subplot(10, 1, 9)
if time_mode == 1:
    ax10 = fig2d.add_subplot(10, 1, 10)

# Y-axis
ax1.set_ylim(f_min, f_max);      ax2.set_ylim(f_min, f_max);      ax3.set_ylim(f_min, f_max)
ax4.set_ylim(f_min, f_max);      ax5.set_ylim(f_min, f_max);      ax6.set_ylim(f_min, f_max)
ax7.set_ylim(f_min, f_max);      ax8.set_ylim(f_min, f_max);      ax9.set_ylim(f_min, f_max)
if f_mode == 1:
    ax1.set_yscale('log');       ax2.set_yscale('log');           ax3.set_yscale('log')
    ax4.set_yscale('log');       ax5.set_yscale('log');           ax6.set_yscale('log')
    ax7.set_yscale('log');       ax8.set_yscale('log');           ax9.set_yscale('log')
ax1.set_ylabel('D.Lin UV'); ax2.set_ylabel('D.Lin VW'); ax3.set_ylabel('D.Lin WU')
ax4.set_ylabel('D.Cir UV'); ax5.set_ylabel('D.Cir VW'); ax6.set_ylabel('D.Cir WU')
ax7.set_ylabel('D.Ang UV'); ax8.set_ylabel('D.Ang VW'); ax9.set_ylabel('D.Ang WU')
ax1.set_title("[" + data_name + "]"''); ax9.set_xlabel(str_date)

# Plot
if time_mode == 1:
    p1 = ax1.pcolormesh(num_1d, freq1, E_DoLuv_2d, norm=colors.Normalize(vmin=-0.01, vmax=1.01), cmap='jet')
    p2 = ax2.pcolormesh(num_1d, freq1, E_DoLvw_2d, norm=colors.Normalize(vmin=-0.01, vmax=1.01), cmap='jet')
    p3 = ax3.pcolormesh(num_1d, freq1, E_DoLwu_2d, norm=colors.Normalize(vmin=-0.01, vmax=1.01), cmap='jet')
    p4 = ax4.pcolormesh(num_1d, freq1, E_DoCuv_2d, norm=colors.Normalize(vmin=-1.01, vmax=1.01), cmap='bwr')
    p5 = ax5.pcolormesh(num_1d, freq1, E_DoCvw_2d, norm=colors.Normalize(vmin=-1.01, vmax=1.01), cmap='bwr')
    p6 = ax6.pcolormesh(num_1d, freq1, E_DoCwu_2d, norm=colors.Normalize(vmin=-1.01, vmax=1.01), cmap='bwr')
    p7 = ax7.pcolormesh(num_1d, freq1, E_ANGuv_2d, norm=colors.Normalize(vmin=-1.00, vmax=181.), cmap='hsv')
    p8 = ax8.pcolormesh(num_1d, freq1, E_ANGvw_2d, norm=colors.Normalize(vmin=-1.00, vmax=181.), cmap='hsv')
    p9 = ax9.pcolormesh(num_1d, freq1, E_ANGwu_2d, norm=colors.Normalize(vmin=-1.00, vmax=181.), cmap='hsv')
    p10 = ax10.plot(np.ravel(Epoch_2d[:]), '.')
    pp3 = fig2d.colorbar(p3, ax=ax10, orientation="vertical"); pp3.set_label(power_str)
else:
    p1 = ax1.pcolormesh(Epoch_2d, freq1, E_DoLuv_2d, norm=colors.Normalize(vmin=-0.01, vmax=1.01), cmap='jet')
    p2 = ax2.pcolormesh(Epoch_2d, freq1, E_DoLvw_2d, norm=colors.Normalize(vmin=-0.01, vmax=1.01), cmap='jet')
    p3 = ax3.pcolormesh(Epoch_2d, freq1, E_DoLwu_2d, norm=colors.Normalize(vmin=-0.01, vmax=1.01), cmap='jet')
    p4 = ax4.pcolormesh(Epoch_2d, freq1, E_DoCuv_2d, norm=colors.Normalize(vmin=-1.01, vmax=1.01), cmap='bwr')
    p5 = ax5.pcolormesh(Epoch_2d, freq1, E_DoCvw_2d, norm=colors.Normalize(vmin=-1.01, vmax=1.01), cmap='bwr')
    p6 = ax6.pcolormesh(Epoch_2d, freq1, E_DoCwu_2d, norm=colors.Normalize(vmin=-1.01, vmax=1.01), cmap='bwr')
    p7 = ax7.pcolormesh(Epoch_2d, freq1, E_ANGuv_2d, norm=colors.Normalize(vmin=-1.00, vmax=181.), cmap='hsv')
    p8 = ax8.pcolormesh(Epoch_2d, freq1, E_ANGvw_2d, norm=colors.Normalize(vmin=-1.00, vmax=181.), cmap='hsv')
    p9 = ax9.pcolormesh(Epoch_2d, freq1, E_ANGwu_2d, norm=colors.Normalize(vmin=-1.00, vmax=181.), cmap='hsv')
pp1 = fig2d.colorbar(p1, ax=ax1, orientation="vertical"); pp2 = fig2d.colorbar(p2, ax=ax2, orientation="vertical")
pp3 = fig2d.colorbar(p3, ax=ax3, orientation="vertical"); pp4 = fig2d.colorbar(p4, ax=ax4, orientation="vertical")
pp5 = fig2d.colorbar(p5, ax=ax5, orientation="vertical"); pp6 = fig2d.colorbar(p6, ax=ax6, orientation="vertical")
pp7 = fig2d.colorbar(p7, ax=ax7, orientation="vertical"); pp8 = fig2d.colorbar(p8, ax=ax8, orientation="vertical")
pp9 = fig2d.colorbar(p9, ax=ax9, orientation="vertical")

# X-axis: Time
if time_mode == 1:
    xlim=[num_1d[0], num_1d[-1]]
    # xlim=[num_1d[0], 100]
    ax10.set_xlim(xlim)
else:
    if t_min==0:
        xlim=[Epoch_2d[0], Epoch_2d[-1]]
    else:
        xlim=[t_min, t_max]
    print("==>", xlim)
ax1.set_xlim(xlim); ax2.set_xlim(xlim); ax3.set_xlim(xlim); ax4.set_xlim(xlim); ax5.set_xlim(xlim); ax6.set_xlim(xlim)
ax7.set_xlim(xlim); ax8.set_xlim(xlim); ax9.set_xlim(xlim)

fig2d.subplots_adjust(hspace=0.01)
plt.show()
if dump_mode == 1:
    png_fname = work_dir+data_name+'_AngT.png'
    if f_mode == 1:
        png_fname = work_dir+data_name+'_AngT-log.png'
    fig2d.savefig(png_fname)

# %% [markdown]
# # CLEANED data

# %%
# RFI rejection:  Mode -- 0:median   1:max reject   2:min
EuEu_c = juice_math.clean_rfi(np.ravel(spec.EuEu), 5, 2)
EvEv_c = juice_math.clean_rfi(np.ravel(spec.EvEv), 5, 2)
EwEw_c = juice_math.clean_rfi(np.ravel(spec.EwEw), 5, 2)
EE_c   = juice_math.clean_rfi(np.ravel(spec.EE),   5, 2)
EuEu_c = EuEu_c.reshape(n_time0, n_freq0);  EvEv_c = EvEv_c.reshape(n_time0, n_freq0)
EwEw_c = EwEw_c.reshape(n_time0, n_freq0);  EE_c   = EE_c.reshape(n_time0, n_freq0)
EuEu_c_2d = EuEu_c.reshape(n_time0 * data.N_block[0], N_frequency);     EuEu_c_2d = EuEu_c_2d.transpose()
EvEv_c_2d = EvEv_c.reshape(n_time0 * data.N_block[0], N_frequency);     EvEv_c_2d = EvEv_c_2d.transpose()
EwEw_c_2d = EwEw_c.reshape(n_time0 * data.N_block[0], N_frequency);     EwEw_c_2d = EwEw_c_2d.transpose()
EE_c_2d   = EE_c.reshape  (n_time0 * data.N_block[0], N_frequency);     EE_c_2d   = EE_c_2d.transpose()

# %%
n0 = 0;  n1 = np.int16(n_time0/2);  n2 = n_time0-1
f_min = f_min0;  f_max = f_max0
p_min = p_min0;  p_max = p_max0

fig = plt.figure(figsize=(14, 11))
ax1 = fig.add_subplot(3, 1, 1);  ax2 = fig.add_subplot(3, 1, 2);  ax3 = fig.add_subplot(3, 1, 3)

ax1.plot(freq1, spec.EuEu[n0][0:N_frequency], ':r', linewidth=1.0, label='uu init')
ax1.plot(freq1, spec.EvEv[n0][0:N_frequency], ':g', linewidth=0.8, label='vv init')
ax1.plot(freq1, spec.EwEw[n0][0:N_frequency], ':b', linewidth=0.6, label='ww init')
ax1.plot(freq1, spec.EuEu[n1][0:N_frequency], '-.r', linewidth=1.0, label='uu half')
ax1.plot(freq1, spec.EvEv[n1][0:N_frequency], '-.g', linewidth=0.8, label='vv half')
ax1.plot(freq1, spec.EwEw[n1][0:N_frequency], '-.b', linewidth=0.6, label='ww half')
ax1.plot(freq1, spec.EuEu[n2][0:N_frequency], '-r', linewidth=1.0, label='uu end')
ax1.plot(freq1, spec.EvEv[n2][0:N_frequency], '-g', linewidth=0.8, label='vv end')
ax1.plot(freq1, spec.EwEw[n2][0:N_frequency], '-b', linewidth=0.6, label='ww end')
ax2.plot(freq1, EuEu_c[n0][0:N_frequency], ':r', linewidth=1.0, label='uu init cleaned')
ax2.plot(freq1, EvEv_c[n0][0:N_frequency], ':g', linewidth=0.8, label='vv init cleaned')
ax2.plot(freq1, EwEw_c[n0][0:N_frequency], ':b', linewidth=0.6, label='ww init cleaned')
ax2.plot(freq1, EuEu_c[n1][0:N_frequency], '-.r', linewidth=1.0, label='uu half cleaned')
ax2.plot(freq1, EvEv_c[n1][0:N_frequency], '-.g', linewidth=0.8, label='vv half cleaned')
ax2.plot(freq1, EwEw_c[n1][0:N_frequency], '-.b', linewidth=0.6, label='ww half cleaned')
ax2.plot(freq1, EuEu_c[n2][0:N_frequency], '-r', linewidth=1.0, label='uu end cleaned')
ax2.plot(freq1, EvEv_c[n2][0:N_frequency], '-g', linewidth=0.8, label='vv end cleaned')
ax2.plot(freq1, EwEw_c[n2][0:N_frequency], '-b', linewidth=0.6, label='ww end cleaned')
ax3.plot(freq1, spec.EuEu[n0][0:N_frequency], ':r', linewidth=1.0, label='uu init')
ax3.plot(freq1, spec.EuEu[n1][0:N_frequency], ':g', linewidth=1.0, label='uu half')
ax3.plot(freq1, spec.EuEu[n2][0:N_frequency], ':b', linewidth=1.0, label='uu end')
ax3.plot(freq1, EuEu_c[n0][0:N_frequency],    '-r', linewidth=1.0, label='uu init cleaned')
ax3.plot(freq1, EuEu_c[n1][0:N_frequency],    '-g', linewidth=1.0, label='uu half cleaned')
ax3.plot(freq1, EuEu_c[n2][0:N_frequency],    '-b', linewidth=1.0, label='uu end cleaned')
ax1.set_yscale('log');      ax2.set_yscale('log');     ax3.set_yscale('log')
if f_mode == 1:
    ax1.set_xscale('log');  ax2.set_xscale('log');     ax3.set_xscale('log')
ax1.set_ylabel(spec.str);   ax2.set_ylabel(spec.str);  ax3.set_xlabel('frequency [Hz]')
#
date1 = data.epoch[n0];  date1 = date1.strftime('%Y/%m/%d %R:%S')
date2 = data.epoch[n1];  date2 = date2.strftime('%Y/%m/%d %R:%S')
date3 = data.epoch[n2];  date3 = date3.strftime('%Y/%m/%d %R:%S')
title_date = date1 + "  -  " + date2 + "  -  " + date3;  ax1.set_title("[" + data_name + "]  " + title_date)
ax1.legend(loc='upper right', fontsize=8); ax2.legend(loc='upper right', fontsize=8); ax3.legend(loc='upper right', fontsize=8)

xlim=[f_min, f_max]
ax1.set_xlim(xlim); ax2.set_xlim(xlim);
ylim=[10**p_min, 10**p_max]
ax1.set_ylim(ylim);  ax2.set_ylim(ylim)

fig.subplots_adjust(hspace=0); fig.show
if dump_mode == 1:
    png_fname = work_dir+data_name+'_spec-c.png'
    if f_mode == 1:
        png_fname = work_dir+data_name+'_spec-log-c.png'
    # fig2d.savefig(png_fname)

# %%
n0 = 0;  n1 = np.int16(n_time0/2);  n2 = n_time0-1
f_min = f_min0;  f_max = f_max0
p_min = p_min0;  p_max = p_max0

fig = plt.figure(figsize=(14, 11))
ax1 = fig.add_subplot(3, 1, 1);  ax2 = fig.add_subplot(3, 1, 2);  ax3 = fig.add_subplot(3, 1, 3)

ax1.plot(freq1, spec.EvEv[n0][0:N_frequency]/spec.EuEu[n0][0:N_frequency], ':r', linewidth=0.8, label='V/U init')
ax1.plot(freq1, spec.EwEw[n0][0:N_frequency]/spec.EuEu[n0][0:N_frequency], ':b', linewidth=0.6, label='W/U init')
ax1.plot(freq1, spec.EvEv[n1][0:N_frequency]/spec.EuEu[n1][0:N_frequency], '-.r', linewidth=0.8, label='V/U half')
ax1.plot(freq1, spec.EwEw[n1][0:N_frequency]/spec.EuEu[n1][0:N_frequency], '-.b', linewidth=0.6, label='W/U half')
ax1.plot(freq1, spec.EvEv[n2][0:N_frequency]/spec.EuEu[n2][0:N_frequency], '-r', linewidth=0.8, label='V/U end')
ax1.plot(freq1, spec.EwEw[n2][0:N_frequency]/spec.EuEu[n2][0:N_frequency], '-b', linewidth=0.6, label='W/U end')
ax2.plot(freq1, EvEv_c[n0][0:N_frequency]/EuEu_c[n0][0:N_frequency],       ':r', linewidth=0.8, label='V/U init cleaned')
ax2.plot(freq1, EwEw_c[n0][0:N_frequency]/EuEu_c[n0][0:N_frequency],       ':b', linewidth=0.6, label='W/U init cleaned')
ax2.plot(freq1, EvEv_c[n1][0:N_frequency]/EuEu_c[n1][0:N_frequency],       '-.r', linewidth=0.8, label='V/U half cleaned')
ax2.plot(freq1, EwEw_c[n1][0:N_frequency]/EuEu_c[n1][0:N_frequency],       '-.b', linewidth=0.6, label='W/U half cleaned')
ax2.plot(freq1, EvEv_c[n2][0:N_frequency]/EuEu_c[n2][0:N_frequency],       '-r', linewidth=0.8, label='V/U end cleaned')
ax2.plot(freq1, EwEw_c[n2][0:N_frequency]/EuEu_c[n2][0:N_frequency],       '-b', linewidth=0.6, label='W/U end cleaned')
ax3.plot(freq1, spec.EuEu[n0][0:N_frequency], ':r', linewidth=1.0, label='uu init')
ax3.plot(freq1, spec.EuEu[n1][0:N_frequency], ':g', linewidth=1.0, label='uu half')
ax3.plot(freq1, spec.EuEu[n2][0:N_frequency], ':b', linewidth=1.0, label='uu end')
ax3.plot(freq1, EuEu_c[n0][0:N_frequency],    '-r', linewidth=1.0, label='uu init cleaned')
ax3.plot(freq1, EuEu_c[n1][0:N_frequency],    '-g', linewidth=1.0, label='uu half cleaned')
ax3.plot(freq1, EuEu_c[n2][0:N_frequency],    '-b', linewidth=1.0, label='uu end cleaned')
ax1.set_yscale('log');      ax2.set_yscale('log');      
ax3.set_yscale('log')
if f_mode == 1:
    ax1.set_xscale('log');  ax2.set_xscale('log');               ax3.set_xscale('log')
ax1.set_ylabel("ratio");    ax2.set_ylabel("ratio - cleaned");   ax3.set_ylabel(spec.str)
#
date1 = data.epoch[n0];  date1 = date1.strftime('%Y/%m/%d %R:%S')
date2 = data.epoch[n1];  date2 = date2.strftime('%Y/%m/%d %R:%S')
date3 = data.epoch[n2];  date3 = date3.strftime('%Y/%m/%d %R:%S')
title_date = date1 + "  -  " + date2 + "  -  " + date3;  ax1.set_title("[" + data_name + "]  " + title_date)
ax1.legend(loc='upper right', fontsize=8); ax2.legend(loc='upper right', fontsize=8); ax3.legend(loc='upper right', fontsize=8)

xlim=[f_min, f_max]
ax1.set_xlim(xlim); ax2.set_xlim(xlim);
# ylim=[10**p_min, 10**p_max]
ylim=[0.5, 2]
ax1.set_ylim(ylim);  ax2.set_ylim(ylim)

fig.subplots_adjust(hspace=0); fig.show
if dump_mode == 1:
    png_fname = work_dir+data_name+'_ratio.png'
    if f_mode == 1:
        png_fname = work_dir+data_name+'_ratio-log.png'
    # fig2d.savefig(png_fname)

# %%
p_min = p_min0+1;    p_max = p_max0-4
f_min = f_min0;      f_max = f_max0

fig2d = plt.figure(figsize=[16,11])
if time_mode == 1:
    ax1 = fig2d.add_subplot(4, 1, 1);  ax2 = fig2d.add_subplot(4, 1, 2);  ax3 = fig2d.add_subplot(4, 1, 3); ax4 = fig2d.add_subplot(4, 1, 4)
    ax4.set_xlabel(str_date)
else:
    ax1 = fig2d.add_subplot(3, 1, 1);  ax2 = fig2d.add_subplot(3, 1, 2);  ax3 = fig2d.add_subplot(3, 1, 3)
    ax3.set_xlabel(str_date)

ax1.set_ylim(f_min0, f_max0);      ax2.set_ylim(f_min0, f_max0);      ax3.set_ylim(f_min0, f_max0)
if f_mode == 1:
    ax1.set_yscale('log');         ax2.set_yscale('log');             ax3.set_yscale('log')
ax1.set_ylabel('EuEu cleaned [kHz]'); ax2.set_ylabel('EvEv cleaned [kHz]'); ax3.set_ylabel('EwEw cleaned [kHz]')
ax1.set_title("[" + data_name + "]")

if time_mode == 1:
    p1 = ax1.pcolormesh(num_1d, freq1, EuEu_c_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p2 = ax2.pcolormesh(num_1d, freq1, EvEv_c_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p3 = ax3.pcolormesh(num_1d, freq1, EwEw_c_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p4 = ax4.plot(np.ravel(Epoch_2d[:]), '.')
    pp3 = fig2d.colorbar(p3, ax=ax4, orientation="vertical"); pp3.set_label(spec.str)
else:
    p1 = ax1.pcolormesh(Epoch_2d, freq1, EuEu_c_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p2 = ax2.pcolormesh(Epoch_2d, freq1, EvEv_c_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p3 = ax3.pcolormesh(Epoch_2d, freq1, EwEw_c_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
pp1 = fig2d.colorbar(p1, ax=ax1, orientation="vertical");  pp1.set_label(spec.str)
pp2 = fig2d.colorbar(p2, ax=ax2, orientation="vertical");  pp2.set_label(spec.str)
pp3 = fig2d.colorbar(p3, ax=ax3, orientation="vertical");  pp3.set_label(spec.str)

# X-axis: Time
if time_mode == 1:
    xlim=[num_1d[0], num_1d[-1]]
    # xlim=[num_1d[0], 100]
    ax4.set_xlim(xlim)
else:
    if t_min==0:
        xlim=[Epoch_2d[0], Epoch_2d[-1]]
    else:
        xlim=[t_min, t_max]
    print("==>", xlim)
ax1.set_xlim(xlim); ax2.set_xlim(xlim); ax3.set_xlim(xlim)

plt.subplots_adjust(hspace=0.03)
plt.show()
if dump_mode == 1:
    png_fname = work_dir+data_name+'_FT-c.png'
    if f_mode == 1:
        png_fname = work_dir+data_name+'_FT-log-c.png'
    # fig2d.savefig(png_fname)

# %%
p_min = p_min0+1.0;  p_max = p_max0-3.5
f_min = f_min0;      f_max = f_max0

fig2d = plt.figure(figsize=[16,11])
if time_mode == 1:
    ax1 = fig2d.add_subplot(2, 1, 1);  ax2 = fig2d.add_subplot(2, 1, 2);  ax2.set_xlabel(str_date)
else:
    ax1 = fig2d.add_subplot(1, 1, 1);                                     ax1.set_xlabel(str_date)

ax1.set_ylim(f_min0, f_max0)
if f_mode == 1:
    ax1.set_yscale('log')
ax1.set_ylabel('EE cleaned [kHz]');  ax1.set_title("[" + data_name + "]")

if time_mode == 1:
    p1 = ax1.pcolormesh(num_1d,   freq1, EE_c_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
    p2 = ax4.plot(np.ravel(Epoch_2d[:]), '.')
    pp1 = fig2d.colorbar(p1, ax=ax2, orientation="vertical"); pp1.set_label(spec.str)
else:
    p1 = ax1.pcolormesh(Epoch_2d, freq1, EE_c_2d, norm=colors.LogNorm(vmin=10**p_min, vmax=10**p_max), cmap='jet')
pp1 = fig2d.colorbar(p1, ax=ax1, orientation="vertical");  pp1.set_label(spec.str)

if time_mode == 1:
    xlim=[num_1d[0], num_1d[-1]]
    # xlim=[num_1d[0], 100]
    ax2.set_xlim(xlim)
else:
    if t_min==0:
        xlim=[Epoch_2d[0], Epoch_2d[-1]]
    else:
        xlim=[t_min, t_max]
    print("==>", xlim)
E_min1 = '2024-08-19 21:07:00';  t_min1 = datetime.datetime.strptime(E_min1, "%Y-%m-%d %H:%M:%S")
E_max1 = '2024-08-19 21:08:30';  t_max1 = datetime.datetime.strptime(E_max1, "%Y-%m-%d %H:%M:%S"); xlim=[t_min1, t_max1]
ax1.set_xlim(xlim)

plt.subplots_adjust(hspace=0.03);  plt.show()
if dump_mode == 1:
    png_fname = work_dir+data_name+'_FT2-c.png'
    if f_mode == 1:
        png_fname = work_dir+data_name+'_FT2-log-c.png'
    # fig2d.savefig(png_fname)
